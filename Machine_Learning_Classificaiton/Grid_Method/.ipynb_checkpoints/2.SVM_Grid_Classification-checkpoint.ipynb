# %%
# SVM Grid search algorithm method
#importing the required Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
# In regression, data splitting is not required. Whereas in Classification it is required
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
# If the predicted values is between the defined range, then standard sccalar is required
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Loading the logistic regression model
from sklearn.svm import SVC

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
# Loading the GridsearchCV 
from sklearn.model_selection import GridSearchCV

# configuring the parameters specific to this model
param_grid = {'kernel':['rbf'],
             'gamma':['auto','scale'],
             'C':[1,10]} 

# Scoring is important in this step. This is equal to R_Square in the regression
# This parameter is suitable for both imbalanced and balanced data
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# In place of f1_weighted, other parameters listed in the above page can be replaced and tested
grid = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [1, 10], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
re=grid.cv_results_
grid_predictions = grid.predict(X_test) 
   
# Importing the confusion matrix object
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
# Importing the f1_score
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9111247448089108

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[77  8]
#  [ 4 45]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        85
#            1       0.85      0.92      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.90      0.91      0.91       134
# weighted avg       0.91      0.91      0.91       134

# %%
# Importing the Receiver operating characteristic - Area under curve ( roc_auc ) score object 
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.9711884753901561)

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.069806      0.015269         0.010915        0.005638        1
# 1       0.014720      0.002092         0.006543        0.001286        1
# 2       0.029096      0.018000         0.019934        0.026372       10
# 3       0.015559      0.001103         0.007487        0.001903       10
#
#   param_gamma param_kernel                                        params  \
# 0        auto          rbf    {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 1       scale          rbf   {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 2        auto          rbf   {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 3       scale          rbf  {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.887346           0.886792           0.850543           0.944161
# 1           0.887346           0.886792           0.850543           0.944161
# 2           0.867478           0.886792           0.869709           0.944161
# 3           0.867478           0.886792           0.869709           0.944161
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.962264         0.906221        0.041022                1
# 1           0.962264         0.906221        0.041022                1
# 2           0.943041         0.902236        0.034431                3
# 3           0.943041         0.902236        0.034431                3

# %%
age_input=float(input("Age:"))
salary_input=float(input("BMI:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age: 35
# BMI: 400
# Sex Male 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,salary_input,sex_male_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]

# %% [markdown]
# #####
